# %% [markdown]
# <a href="https://colab.research.google.com/github/wgu3/School-Management-System/blob/main/School_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:
    def __init__(self,std_ID,std_name,std_age,std_gender,std_cgpa,std_city,std_program):
        self.std_ID=std_ID
        self.std_name=std_name
        self.std_age=std_age
        self.std_gender=std_gender
        self.std_cgpa=std_cgpa
        self.std_city=std_city
        self.std_program=std_program
        
    def insertStudent(self, std_ID, std_name, std_age, std_gender, std_cgpa,std_city,std_program):
        ob = Student(std_ID, std_name, std_age, std_gender, std_cgpa,std_city,std_program)
        list_student.append(ob)

    def displayStudent(self,ob):
        print("\n--------------Student Information------------------")
        print(f"            Student ID:         {ob.std_ID}       ")
        print(f"            Name:               {ob.std_name}       ")
        print(f"            Age:                {ob.std_age}       ")
        print(f"            Gender:             {ob.std_gender}       ")
        print(f"            Cgpa:               {ob.std_cgpa}       ")
        print(f"            City:               {ob.std_city}       ")
        print(f"            Program:            {ob.std_program}       ")
    
# Search Function

    def searchStudent(self, std_ID):
        for i in range(len(list_student)):
            if (list_student[i].std_ID == std_ID):
                return i

# Delete Function

    def deleteStudent(self, std_ID):
        i = obj.searchStudent(std_ID)
        del list_student[i]

# Update Function

    def updateStudent(self, std_ID):
        i = obj.searchStudent(std_ID)
        print("\nWhich field do you want to update?")
        print("1. Name")
        print("2. Age")
        print("3. Gender")
        print("4. Cgpa")
        print("5. City")
        print("6. Program")
        option = int(input())
        if (option == 1):
            name = input("> Please provide the new name: ")
            list_student[i].std_name = name
        elif (option == 2):
            age = input("> Please provide the new age: ")
            list_student[i].std_age = age
        elif (option == 3):
            gender = input("> Please provide the gender: ")
            list_student[i].std_gender = gender
        elif (option == 4):
            cgpa = input("> Please enter the new cgpa: ")
            list_student[i].std_cgpa = cgpa
        elif (option == 5):
            city = input("> Please enter the new city: ")
            list_student[i].std_city = city
        elif (option == " " or option == ""):
            print("> Please enter a valid choice")
        else:
            program = input("> Please enter the new program: ")
            list_student[i].std_program = program
            print("\n")
class Teacher:
    def __init__(self,t_ID,t_name,t_age,t_gender,t_salary,t_city,t_specialty):
        self.t_ID=t_ID
        self.t_name=t_name
        self.t_age=t_age
        self.t_gender=t_gender
        self.t_salary=t_salary
        self.t_city=t_city
        self.t_specialty=t_specialty
        
    def insertTeacher(self, t_ID, t_name, t_age, t_gender, t_salary, t_city, t_specialty):
        ob = Teacher(t_ID, t_name, t_age, t_gender, t_salary, t_city, t_specialty)
        list_teacher.append(ob)

    def displayTeacher(self,ob):
        print("\n--------------Teacher Information------------------")
        print(f"            Teacher ID:         {ob.t_ID}       ")
        print(f"            Name:               {ob.t_name}       ")
        print(f"            Age:                {ob.t_age}       ")
        print(f"            Gender:             {ob.t_gender}       ")
        print(f"            Salary:             {ob.t_salary}       ")
        print(f"            City:               {ob.t_city}       ")
        print(f"            Specialty:          {ob.t_specialty}       ")
    
# Search Function

    def searchTeacher(self, t_ID):
        for i in range(len(list_teacher)):
            if (list_teacher[i].t_ID == t_ID):
                return i

# Delete Function

    def deleteTeacher(self, t_ID):
        i = obj.searchTeacher(t_ID)
        del list_teacher[i]

# Update Function

    def updateTeacher(self, t_ID):
        i = obj.searchTeacher(t_ID)
        print("\nWhich field do you want to update?")
        print("1. Name")
        print("2. Age")
        print("3. Gender")
        print("4. Salary")
        print("5. City")
        print("6. Specialty")
        option = int(input())
        if (option == 1):
            name = input("> Please provide the new name: ")
            list_teacher[i].t_name = name
        elif (option == 2):
            age = input("> Please provide the new age: ")
            list_teacher[i].t_age = age
        elif (option == 3):
            gender = input("> Please provide the gender: ")
            list_teacher[i].t_gender = gender
        elif (option == 4):
            cgpa = input("> Please enter the new salary: ")
            list_teacher[i].t_salary = salary
        elif (option == 5):
            city = input("> Please enter the new city: ")
            list_teacher[i].t_city = city
        elif (option == " " or option == ""):
            print("> Please enter a valid choice")
        else:
            program = input("> Please enter the new specialty: ")
            list_teacher[i].t_specialty = specialty
            print("\n")
            
class Admin:
    def __init__(self,a_ID,a_name,a_age,a_gender,a_salary,a_city,a_dept):
        self.a_ID=a_ID
        self.a_name=a_name
        self.a_age=a_age
        self.a_gender=a_gender
        self.a_salary=a_salary
        self.a_city=a_city
        self.a_dept=a_dept
        
    def insertAdmin(self, a_ID, a_name, a_age, a_gender, a_salary, a_city, a_dept):
        ob = Admin(a_ID, a_name, a_age, a_gender, a_salary, a_city, a_dept)
        list_admin.append(ob)

    def displayAdmin(self,ob):
        print("\n--------------Admin Information------------------")
        print(f"            Admin ID:           {ob.a_ID}       ")
        print(f"            Name:               {ob.a_name}       ")
        print(f"            Age:                {ob.a_age}       ")
        print(f"            Gender:             {ob.a_gender}       ")
        print(f"            Salary:             {ob.a_salary}       ")
        print(f"            City:               {ob.a_city}       ")
        print(f"            Department:         {ob.a_dept}       ")
    
# Search Function

    def searchAdmin(self, a_ID):
        for i in range(len(list_admin)):
            if (list_admin[i].a_ID == a_ID):
                return i

# Delete Function

    def deleteAdmin(self, a_ID):
        i = obj.searchAdmin(a_ID)
        del list_admin[i]

# Update Function

    def updateAdmin(self, a_ID):
        i = obj.searchAdmin(a_ID)
        print("\nWhich field do you want to update?")
        print("1. Name")
        print("2. Age")
        print("3. Gender")
        print("4. Salary")
        print("5. City")
        print("6. Department")
        option = int(input())
        if (option == 1):
            name = input("> Please provide the new name: ")
            list_admin[i].a_name = name
        elif (option == 2):
            age = input("> Please provide the new age: ")
            list_admin[i].a_age = age
        elif (option == 3):
            gender = input("> Please provide the gender: ")
            list_admin[i].a_gender = gender
        elif (option == 4):
            cgpa = input("> Please enter the new salary: ")
            list_admin[i].a_salary = salary
        elif (option == 5):
            city = input("> Please enter the new city: ")
            list_admin[i].a_city = city
        elif (option == " " or option == ""):
            print("> Please enter a valid choice")
        else:
            program = input("> Please enter the new specialty: ")
            list_admin[i].a_specialty = Department
            print("\n")
    
while True:    
    print("\n =========================================\n")
    print("Welcome to St Andrews Management System!")
    print("Press (1) if you are a student.")
    print("Press (2) if you are a teacher.")
    print("Press (3) if you are an admin.")
    print("Press (0) if you wish to exit.")
    print("\n =========================================\n")
    choice = int(input())
    if choice == 0:
        print("Thank your for your time")
        break 
    elif choice == " " or choice == "":
            print("> Please enter a valid choice")
    elif choice == 1:
        list_student = []
        obj = Student(0, '', 0, '', 0, '','')
        while True:
            print("\n******************************\n")
            print("Welcome to the Student Records!")
            print("Press 1 to insert new student data")
            print("Press 2 to display student data")
            print("Press 3 to search for student data")
            print("Press 4 to delete student data")
            print("Press 5 to update student data")
            print("Press 0 if you wish to exit")
            print("\n******************************\n")
            ch = int(input())
            if (ch == 0):
              break
            elif (ch == " " or ch == ""):
              print("> Please enter a valid choice")
            elif (ch == 1):
                while True:
                    std_id = int(input("Enter the student ID: "))
                    std_name = input("Enter the student name: ")
                    std_age = int(input("Enter the student age: "))
                    std_gender = input("Enter the gender of the student: ")
                    std_cgpa = float(input("Enter the gpa of the student: "))
                    std_city = input("Enter the city of the student: ")
                    std_program = input("Enter the program of the student: ")
                    obj.insertStudent(std_id, std_name, std_age, std_gender,
                                      std_cgpa,std_city,std_program)
                    choice = input("\n> Do you want to continue? Yes or No?")
                    if (choice == 'Yes' or choice == 'yes'):
                        continue
                    elif (choice == 'No' or choice == 'no'):
                        break
                    else:
                      print("> Please enter a valid choice.")
                    print("\n")
            elif (ch == 2):
                print("\n")
                print("\nList of Students\n")
                for i in range(list_student.__len__()):
                    obj.displayStudent(list_student[i])

            elif (ch == 3):
                while True:
                    n = int(input("Enter the student ID for the record you want to search: "))
                    s = obj.searchStudent(n)
                    obj.displayStudent(list_student[s])
                    choice = input("\n> Do you want to continue? Yes or No? ")
                    if (choice == 'Yes' or choice == 'yes'):
                        continue
                    elif (choice == 'No' or choice == 'no'):
                        break
                    elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")
                    print("\n")

            elif (ch == 4):
                while True:
                    d = int(input("Enter the student ID for the record you want to delete: "))
                    obj.deleteStudent(d)
                    print(list_student.__len__())
                    print("\n>> List after deletion << ")
                    for i in range(list_student.__len__()):
                        obj.displayStudent(list_student[i])
                    choice = input("\n> Do you want to continue? Yes or No? ")
                    if (choice == 'Yes' or choice == 'yes'):
                        continue
                    elif (choice == 'No' or choice == 'no'):
                        break
                    elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")
                    print("\n")

            elif (ch == 5):
                while True:
                    u = int(input( "Enter the student ID for the record you want to update: "))
                    obj.updateStudent(u)
                    print(list_student.__len__())
                    print("\n>> List after updation <<")
                    for i in range(list_student.__len__()):
                        obj.displayStudent(list_student[i])
                    choice = input("\n> Do you want to continue? Yes or No? ")
                    if (choice == 'Yes' or choice == 'yes'):
                        continue
                    elif (choice == 'No' or choice == 'no'):
                        break
                    elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")
                    print("\n")
            else:
                print("Thanks for your time!")
                choice = input("\n> Do you want to continue? Yes or No? ")
                if (choice == 'Yes' or choice == 'yes'):
                    continue
                elif (choice == 'No' or choice == 'no'):
                    print("> Thank you for your time")
                    break
                elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")
                print("\n")
    elif choice == 2:
        list_teacher = []
        obj = Teacher(0, '', 0, '', 0, '','')
        while True:
            print("\n******************************\n")
            print("Welcome to the Teacher Records!")
            print("Press 1 to insert new teacher data")
            print("Press 2 to display teacher data")
            print("Press 3 to search for teacher data")
            print("Press 4 to delete teacher data")
            print("Press 5 to update teacher data")
            print("Press 0 if you wish to exit")
            print("\n******************************\n")
            ch = int(input())
            if (ch == 0):
              break
            elif (ch == " " or ch == ""):
              print("> Please enter a valid choice")
            elif (ch == 1):
                while True:
                    t_id = int(input("Enter the teacher ID: "))
                    t_name = input("Enter the teacher name: ")
                    t_age = int(input("Enter the teacher age: "))
                    t_gender = input("Enter the gender of the teacher: ")
                    t_salary = int(input("Enter the salary of the teacher: "))
                    t_city = input("Enter the city of the teacher: ")
                    t_specialty = input("Enter the specialty of the teacher: ")
                    obj.insertTeacher(t_id, t_name, t_age, t_gender,
                                      t_salary,t_city,t_specialty)
                    choice = input("\n> Do you want to continue? Yes or No? ")
                    if (choice == 'Yes' or choice == 'yes'):
                        continue
                    elif (choice == 'No' or choice == 'no'):
                        break
                    elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")
                    print("\n")

            elif (ch == 2):
                print("\n")
                print("\nList of Teachers\n")
                for i in range(list_teacher.__len__()):
                    obj.displayTeacher(list_teacher[i])

            elif (ch == 3):
                while True:
                    n = int(input("Enter the teacher ID for the record you want to search: "))
                    s = obj.searchTeacher(n)
                    obj.displayTeacher(list_teacher[s])
                    choice = input("\n> Do you want to continue? Yes or No? ")
                    if (choice == 'Yes' or choice == 'yes'):
                        continue
                    elif (choice == 'No' or choice == 'no'):
                        break
                    elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")
                    print("\n")

            elif (ch == 4):
                while True:
                    d = int(input("Enter the teacher ID for the record you want to delete: "))
                    obj.deleteTeacher(d)
                    print(list_teacher.__len__())
                    print("\n>> List after deletion<<")
                    for i in range(list_teacher.__len__()):
                        obj.displayTeacher(list_teacher[i])
                    choice = input("\n> Do you want to continue? Yes or No? ")
                    if (choice == 'Yes' or choice == 'yes'):
                        continue
                    elif (choice == 'No' or choice == 'no'):
                        break
                    elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")
                    print("\n")

            elif (ch == 5):
                while True:
                    u = int(input( "Enter the teacher ID for the record you want to update: "))
                    obj.updateTeacher(u)
                    print(list_teacher.__len__())
                    print("\n>> List after updation << ")
                    for i in range(list_teacher.__len__()):
                        obj.displayTeacher(list_teacher[i])
                    choice = input("\n> Do you want to continue? Yes or No? ")
                    if (choice == 'Yes' or choice == 'yes'):
                        continue
                    elif (choice == 'No' or choice == 'no'):
                        break
                    elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")
                    print("\n")
            else:
                print("Thanks for your time!")
                choice = input("\n> Do you want to continue? Yes or No? ")
                if (choice == 'Yes' or choice == 'yes'):
                    continue
                elif (choice == 'No' or choice == 'no'):
                    print("> Thank you for your time")
                    break    
                elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")   
                print("\n")                         
    elif choice == 3:
        list_admin = []
        obj = Admin(0, '', 0, '', 0, '','')
        while True:
            print("\n******************************\n")
            print("Welcome to the Admin Records!")
            print("Press 1 to insert new admin data")
            print("Press 2 to display admin data")
            print("Press 3 to search for admin data")
            print("Press 4 to delete admin data")
            print("Press 5 to update admin data")
            print("Press 0 if you wish to exit")
            print("\n******************************\n")
            ch = int(input())
            if (ch == 0):
              break
            elif (ch == " " or ch == ""):
              print("> Please enter a valid choice")
            elif (ch == 1):
                while True:
                    a_id = int(input("Enter the admin ID: "))
                    a_name = input("Enter the admin name: ")
                    a_age = int(input("Enter the admin age: "))
                    a_gender = input("Enter the gender of the admin: ")
                    a_salary = int(input("Enter the salary of the admin: "))
                    a_city = input("Enter the city of the admin: ")
                    a_dept = input("Enter the department of the admin: ")
                    obj.insertAdmin(a_id, a_name, a_age, a_gender,
                                      a_salary,a_city,a_dept)
                    choice = input("\n > Do you want to continue? Yes or No? ")
                    if (choice == 'Yes' or choice == 'yes'):
                        continue
                    elif (choice == 'No' or choice == 'no'):
                        break
                    elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")
                    print("\n")
            elif (ch == 2):
                print("\n")
                print("\nList of Admins")
                for i in range(list_admin.__len__()):
                    obj.displayAdmin(list_admin[i])

            elif (ch == 3):
                while True:
                    n = int(input("Enter the admin ID for the record you want to search: "))
                    s = obj.searchAdmin(n)
                    obj.displayAdmin(list_admin[s])
                    choice = input("\n> Do you want to continue? Yes or No? ")
                    if (choice == 'Yes' or choice == 'yes'):
                        continue
                    elif (choice == 'No' or choice == 'no'):
                        break
                    elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")
                    print("\n")

            elif (ch == 4):
                while True:
                    d = int(input("Enter the admin ID for the record you want to delete: "))
                    obj.deleteAdmin(d)
                    print(list_admin.__len__())
                    print("\n>> List after deletion <<")
                    for i in range(list_admin.__len__()):
                        obj.displayAdmin(list_admin[i])
                    choice = input("> Do you want to continue? Yes or No? ")
                    if (choice == 'Yes' or choice == 'yes'):
                        continue
                    elif (choice == 'No' or choice == 'no'):
                        break
                    elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")
                    print("\n")

            elif (ch == 5):
                while True:
                    u = int(input( "Enter the admin ID for the record you want to update: "))
                    obj.updateAdmin(u)
                    print(list_admin.__len__())
                    print("\n>> List after updation <<")
                    for i in range(list_admin.__len__()):
                        obj.displayAdmin(list_admin[i])
                    choice = input("\n> Do you want to continue? Yes or No? ")
                    if (choice == 'Yes' or choice == 'yes'):
                        continue
                    elif (choice == 'No' or choice == 'no'):
                        break
                    elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")
                    print("\n")
            else:
                print("Thanks for your time!")
                choice = input("\n> Do you want to continue? Yes or No? ")
                if (choice == 'Yes' or choice == 'yes'):
                    continue
                elif (choice == 'No' or choice == 'no'):
                    print("> Thank you for your time")
                    break      
                elif (choice == " " or choice == ""):
                      print("> Please enter a valid choice.")   
                print("\n")
# Out:
# ...
#
# Welcome to St Andrews Management System!
# Press (1) if you are a student.
# Press (2) if you are a teacher.
# Press (3) if you are an admin.
# Press (0) if you wish to exit.
#
# ...
#
#
# ******************************
#
# Welcome to the Admin Records!
# Press 1 to insert new admin data
# Press 2 to display admin data
# Press 3 to search for admin data
# Press 4 to delete admin data
# Press 5 to update admin data
# Press 0 if you wish to exit
#
# ******************************
#
#
# ******************************
#
# Welcome to the Admin Records!
# Press 1 to insert new admin data
# Press 2 to display admin data
# Press 3 to search for admin data
# Press 4 to delete admin data
# Press 5 to update admin data
# Press 0 if you wish to exit
#
# ******************************
#
#
# Which field do you want to update?
# 1. Name
# 2. Age
# 3. Gender
# 4. Salary
# 5. City
# 6. Department
# 1
#
# >> List after updation <<
#
# --------------Admin Information------------------
# ...
